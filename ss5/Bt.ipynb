# %%
# Bt1
file_path = "doc.txt"
file = open(file_path, "r", encoding="utf-8")
content = file.read()
print(content)
with open(file_path, "a", encoding="utf-8") as file:
    file.write(input("Nhập nội dung muốn ghi vào file: "))
# Out:
# xin chào 123

# %%
# bt2
import csv

with open('ss5/students.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f)

    data = []
    try:
        header = next(reader)
    except StopIteration:
        header = []
    else:
        for row in reader:
            if row and float(row[2]) >= 7:
                data.append(row)

for row in data:
    print(row)

if header:
    with open('ss5/high_grade_students.csv', 'w', encoding='utf-8', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerows(data)

# %%
# bt3
import json
import os

if not os.path.exists('ss5/user_data.json') or os.stat('ss5/user_data.json').st_size == 0:
    with open('user_data.json', 'w', encoding='utf-8') as f:
        json.dump([], f)

with open('ss5/user_data.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

for user in data:
    if user.get('id') == 3:
        print(f"Tên: {user.get('name')}, Tuổi: {user.get('age')}")
        break

new_user = {
    "id": 4,
    "name": "Nguyen Van A",
    "age": 30
}

data.append(new_user)

with open('ss5/user_data.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
# Bt7
from pathlib import Path

folder = Path('ss5')

for file in folder.iterdir():
    if file.is_file() and file.suffix == '.txt':
        print(file.name)

# %%
# Bt8
from datetime import datetime
import os

filename = 'ss5/log.txt'

if not os.path.exists(filename):
    print("File không tồn tại.")
else:
    today = datetime.today().date()
    timestamp_format = '%Y-%m-%d %H:%M:%S'

    with open(filename, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split(' ', 2)
            if len(parts) < 3:
                continue

            timestamp_str = parts[0] + ' ' + parts[1]

            try:
                timestamp = datetime.strptime(timestamp_str, timestamp_format)
                if timestamp.date() == today:
                    print(line.strip())
            except ValueError:
                continue

# %%
# Bt4
import os

filename = input("Nhập tên file cần kiểm tra: ")

if os.path.exists(filename):
    print("File đã tồn tại.")
else:
    print("File không tồn tại.")

# %%
# bt5
filename = 'ss5/sample.txt'

with open(filename, 'r', encoding='utf-8') as f:
    content = f.read()

words = content.split()
print("Số từ trong file:", len(words))

# %%
# Bt6
import json

with open('ss5/inventory.json', 'r', encoding='utf-8') as f:
    products = json.load(f)

new_product = {
    "product_id": 4,
    "name": "Sản phẩm mới",
    "quantity": 10,
    "price": 150000
}

products.append(new_product)

with open('ss5/inventory.json', 'w', encoding='utf-8') as f:
    json.dump(products, f, ensure_ascii=False, indent=4)
